# %% [markdown]
# 링크 : https://wikidocs.net/44249

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.3.0)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from konlpy) (0.4.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)

# %%
import pandas as pd
import urllib.request
import matplotlib.pyplot as plt
import re
from konlpy.tag import Okt
from tqdm import tqdm
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# 데이터 로드 
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x7f03b66aa310>)

# %%
# 훈련데이터와 테스트데이터 판다스로 변경
train_data = pd.read_table('ratings_train.txt')
test_data = pd.read_table('ratings_test.txt')

# %%
# 훈련데이터와 테스트데이터 판다스로 변경
train_data = pd.read_table('ratings_train.txt')
test_data = pd.read_table('ratings_test.txt')

print('훈련용 리뷰 개수 :',len(train_data))
# Out:
# 훈련용 리뷰 개수 : 150000

# %%
train_data[:2]
# Out:
#         id                           document  label
# 0  9976970                아 더빙.. 진짜 짜증나네요 목소리      0
# 1  3819312  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1

# %%
test_data[:2]
# Out:
#         id              document  label
# 0  6270596                   굳 ㅋ      1
# 1  9274899  GDNTOPCLASSINTHECLUB      0

# %%
# 훈련데이터 정재

# 중복 체크
train_data['document'].nunique(), train_data['label'].nunique()

# 중복 제거
train_data.drop_duplicates(subset=['document'], inplace=True)

# 중복 제거된 데이터 확인
print('중복 제거한 총 샘플의 수 :',len(train_data))
# Out:
# 중복 제거한 총 샘플의 수 : 146183

# %%
train_data['label'].value_counts().plot(kind = 'bar')
print(train_data.groupby('label').size().reset_index(name = 'count'))
# Out:
#    label  count
# 0      0  73342
# 1      1  72841

# %%
# Null 값 유무 확인
print(train_data.isnull().values.any())

# Null 값을 가진 컬럼 확인
print(train_data.isnull().sum())

# Null 값을 가진 인덱스 확인
train_data.loc[train_data.document.isnull()]

# Null 값이 존재하는 행 제거
train_data = train_data.dropna(how = 'any') 

# Null 값 제거 후 총 샘플 수 확인
print(len(train_data))
# Out:
# True
# id          0
# document    1
# label       0
# dtype: int64
# 146182

# %%
# 한글과 공백을 제외하고 모두 제거
# ㄱ~ㅎ,ㅏ~ㅣ,가-힣, 
train_data['document'] = train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
train_data[:2]
# Out:
#         id                    document  label
# 0  9976970           아 더빙 진짜 짜증나네요 목소리      0
# 1  3819312  흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나      1

# %%
# 한글과 공백을 제외하고 모두 제거한 후 생겨난 Null 값이 있는지 확인
train_data['document'] = train_data['document'].str.replace('^ +', "") 
train_data['document'].replace('', np.nan, inplace=True)
print(train_data.isnull().sum())
# Out:
# id            0
# document    789
# label         0
# dtype: int64

# %%
# Null 값이 있는 테이블 확인
train_data.loc[train_data.document.isnull()][:5]
# Out:
#            id document  label
# 404   4221289      NaN      0
# 412   9509970      NaN      1
# 470  10147571      NaN      1
# 584   7117896      NaN      0
# 593   6478189      NaN      0

# %%
# Null 값이 있는 테이블 다시 제거
train_data = train_data.dropna(how = 'any')
print(len(train_data))
# Out:
# 145393

# %%
# 테스트 데이터 정재

# document 열에서 중복인 내용이 있다면 중복 제거
test_data.drop_duplicates(subset = ['document'], inplace=True) 

# 한글과 공백을 제외하고 모두 제거
test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") 

# 공백은 empty 값으로 변경
test_data['document'] = test_data['document'].str.replace('^ +', "") 

# 공백은 Null 값으로 변경
test_data['document'].replace('', np.nan, inplace=True)

# Null 값 제거
test_data = test_data.dropna(how='any') 
print('전처리 후 테스트용 샘플의 개수 :',len(test_data))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 48852

# %%
# 토큰화

# 불용어
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# 형태소 분석 테스트
okt = Okt()
okt.morphs('와 이런 것도 영화라고 차라리 뮤직비디오를 만드는 게 나을 뻔', stem = True)
# Out:
# ['오다', '이렇다', '것', '도', '영화', '라고', '차라리', '뮤직비디오', '를', '만들다', '게', '나다', '뻔']

# %%
# 훈련데이터 토큰화

X_train = []
for sentence in tqdm(train_data['document']):
    tokenized_sentence = okt.morphs(sentence, stem=True)
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] 
    X_train.append(stopwords_removed_sentence)
# Out:
#   9%|▉         | 13256/145393 [00:55<09:13, 238.61it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-b419fe06a1f5> in <module>()
#       3 X_train = []
#       4 for sentence in tqdm(train_data['document']):
# ----> 5     tokenized_sentence = okt.morphs(sentence, stem=True)
#       6     stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords]
#       7     X_train.append(stopwords_removed_sentence)
#
# /usr/local/lib/python3.7/dist-packages/konlpy/tag/_okt.py in morphs(self, phrase, norm, stem)
#      76         """Parse phrase to morphemes."""
#      77
# ---> 78         return [s for s, t in self.pos(phrase, norm=norm, stem=stem)]
#      79
#      80     def phrases(self, phrase):
#
# /usr/local/lib/python3.7/dist-packages/konlpy/tag/_okt.py in pos(self, phrase, norm, stem, join)
#      61                     phrase,
#      62                     jpype.java.lang.Boolean(norm),
# ---> 63                     jpype.java.lang.Boolean(stem)).toArray()
#      64         if join:
#      65             return [t for t in tokens]
#
# KeyboardInterrupt:

# %%
# 테스트데이터 토큰화

X_test = []
for sentence in tqdm(test_data['document']):
    tokenized_sentence = okt.morphs(sentence, stem=True) 
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] 
    X_test.append(stopwords_removed_sentence)

# %%
print('전처리 후 테스트용 샘플의 개수 :',len(X_test))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 48852

# %%
# 정수 인코딩

tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

print(tokenizer.word_index)
print(tokenizer.word_counts.items())
# Out:
# {'영화': 1, '보다': 2, '을': 3, '없다': 4, '이다': 5, '있다': 6, '좋다': 7, '너무': 8, '다': 9, '정말': 10, '만': 11, '재밌다': 12, '적': 13, '되다': 14, '같다': 15, '진짜': 16, '아니다': 17, '로': 18, '점': 19, '않다': 20, '에서': 21, '만들다': 22, '연기': 23, '나오다': 24, '평점': 25, '것': 26, '안': 27, '최고': 28, '인': 29, '내': 30, '나': 31, '못': 32, '그': 33, '스토리': 34, '드라마': 35, '왜': 36, '사람': 37, '보고': 38, '생각': 39, '감동': 40, '게': 41, '이렇다': 42, '고': 43, '아깝다': 44, '감독': 45, '때': 46, '더': 47, 'ㅋㅋ': 48, '그냥': 49, '말': 50, '시간': 51, '배우': 52, '재미': 53, '거': 54, '아': 55, '요': 56, '재미없다': 57, '재미있다': 58, '내용': 59, '지루하다': 60, '까지': 61, '하고': 62, '중': 63, '자다': 64, '뭐': 65, '네': 66, '주다': 67, '가다': 68, '작품': 69, '모르다': 70, '쓰레기': 71, '수': 72, '들다': 73, '알다': 74, '지': 75, '하나': 76, '그렇다': 77, '싶다': 78, '사랑': 79, '정도': 80, '이건': 81, '다시': 82, '볼': 83, '이렇게': 84, '액션': 85, '마지막': 86, '최악': 87, 'ㅋ': 88, '저': 89, '개': 90, 'ㅠㅠ': 91, '느낌': 92, '완전': 93, '기': 94, '연출': 95, '돈': 96, '주인공': 97, '걸': 98, '차다': 99, 'ㅋㅋㅋ': 100, '처음': 101, '역시': 102, '하': 103, 'ㅡㅡ': 104, '오다': 105, '많다': 106, '지금': 107, '장면': 108, '이야기': 109, '안되다': 110, '임': 111, '명작': 112, '끝': 113, '나다': 114, '받다': 115, '년': 116, '라': 117, '남다': 118, '별': 119, '별로': 120, '인데': 121, '넘다': 122, '일': 123, '부터': 124, '면': 125, '이나': 126, '버리다': 127, '그리고': 128, '서': 129, '듯': 130, '괜찮다': 131, '또': 132, '많이': 133, '라고': 134, '꼭': 135, '이고': 136, '대': 137, '아름답다': 138, '느끼다': 139, '먹다': 140, '좋아하다': 141, '이런': 142, '해주다': 143, '인생': 144, '분': 145, '이영화': 146, '때문': 147, '난': 148, '무슨': 149, '두': 150, '이해': 151, '소재': 152, '야': 153, '멋지다': 154, '결말': 155, '에게': 156, '영': 157, '어떻다': 158, '여': 159, '성': 160, '엔': 161, '전': 
닌', 1), ('표절', 21), ('인', 519), ('이해', 147), ('왜', 464), ('뒤', 45), ('갈수록', 50), ('없어지다', 14), ('이건', 249), ('깨알', 8), ('캐스팅', 53), ('질퍽', 1), ('하', 208), ('지', 275), ('산뜻하다', 2), ('내', 516), ('용구성', 2), ('자다', 335), ('버무러진', 1), ('일드', 5), ('약탈', 1), ('위', 88), ('변명', 3), ('이르다', 41), ('저', 222), ('놈', 70), ('착하다', 22), ('절대', 77), ('아니다', 710), ('걸', 213), ('요', 361), ('나름', 74), ('심오하다', 5), ('뜻', 14), ('듯', 164), ('그냥', 391), ('학생', 17), ('선생', 3), ('놀다', 12), ('웃다', 82), ('건', 75), ('불가능하다', 5), ('재미없다', 353), ('지루하다', 350), ('같다', 769), ('음식', 8), ('인데', 174), ('바베트', 1), ('만찬', 2), ('하고', 340), ('넘다', 174), ('차이', 15), ('남바', 1), ('베트', 1), ('게', 435), ('별로', 176), ('안', 540), ('핀란드', 2), ('풍경', 7), ('이라도', 48), ('구', 41), ('경', 13), ('할랫', 1), ('늘다', 101), ('ㅡㅡ', 207), ('평범하다', 22), ('수작', 63), ('이라', 93), ('는걸', 15), ('말씀드리다', 1), ('주제', 40), ('중반', 20), ('짤랐을꺼', 1), ('야', 146), ('그래서', 44), ('납득', 8), ('수', 294), ('그렇다', 268), ('꼭', 160), ('고추', 6), ('털다', 2), ('버리다', 167), ('카밀라', 1), ('벨', 3), ('발연기', 44), ('재밋는뎅', 1), ('센스', 6), ('연출', 216), ('력', 74), ('탁월하다', 9), ('점', 678), ('엄포스', 1), ('위력', 4), ('다시', 249), ('한번', 138), ('깨닫다', 12), ('해주다', 154), ('적남', 1), ('꽃', 10), ('검사', 6), ('님', 118), ('완전', 218), ('명품', 10), ('졸', 6), ('쓰레기', 300), ('진부하다', 45), ('도안', 10), ('돼다', 98), ('ㅋㅋ', 392), ('아시', 6), ('간', 55), ('재밌다', 804), ('이리', 43), ('라도', 30), ('기대하다', 85), ('죄인', 3), ('아직도', 74), ('인생', 152), ('최고', 533), ('패션', 4), ('대한', 96), ('열정', 16), ('안나', 28), ('윈', 2), ('투어', 1), ('키이라', 3), ('나이틀리', 1), ('대체', 44), ('정신장애', 1), ('틱장애', 3), ('허허', 8), ('원', 60), ('작가', 84), ('정신', 59), ('나가다', 59), ('유령', 5), ('재미있다', 352), ('관객', 47), ('명', 44), ('이네', 87), ('이렇게', 237), ('평가', 47), ('받다', 190), ('모르다', 303), ('단순하다', 22) ...

# %%
threshold = 3

# 단어의 수
total_cnt = len(tokenizer.word_index) 

# 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
rare_cnt = 0 

# 훈련 데이터의 전체 단어 빈도수 총 합
total_freq = 0

# 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합
rare_freq = 0 

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 14245
# 등장 빈도가 2번 이하인 희귀 단어의 수: 9140
# 단어 집합에서 희귀 단어의 비율: 64.16286416286417
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 7.70079268835769

# %%
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 5106

# %%
tokenizer = Tokenizer(vocab_size) 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-28fdde15dfd5> in <module>()
#       1 tokenizer = Tokenizer(vocab_size)
# ----> 2 tokenizer.fit_on_texts(x_train)
#       3 x_train = tokenizer.texts_to_sequences(x_train)
#       4 x_test = tokenizer.texts_to_sequences(x_test)
#       5
#
# NameError: name 'x_train' is not defined

# %%
y_train = np.array(train_data['label'])
y_test = np.array(test_data['label'])

# %%
print(len(X_train))
print(len(y_train))
# Out:
# 13256
# 145393

# %%
print(X_train[:3])
# Out:
# [[55, 635, 16, 274, 819], [721, 355, 38, 636, 1, 167, 1517, 23, 849, 722, 20], [366, 1877, 2031, 3972, 2, 218, 9]]

# %%
drop_train = [index for index, sentence in enumerate(X_train) if len(sentence) < 1]
drop_test = [index for index, sentence in enumerate(X_test) if len(sentence) < 1]

# %%
print(drop_train)
# Out:
# [28, 169, 398, 414, 546, 1091, 1149, 1347, 1484, 1572, 1711, 1940, 1957, 2201, 2321, 2345, 2432, 3233, 3273, 3439, 3440, 4155, 4289, 4612, 4809, 4857, 5021, 5722, 6408, 6418, 7141, 7149, 7273, 7342, 7790, 8295, 8343, 8677, 8931, 9343, 9660, 9718, 9884, 10352, 10596, 10815, 10973, 11136, 11669, 11897, 12020, 12456, 12504, 12531, 12714, 12716, 12722, 12766, 12896, 12993]

# %%
len(drop_train)
# Out:
# 60

# %%
X_train = np.delete(X_train, drop_train, axis=0)
y_train = np.delete(y_train, drop_train, axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
print(len(X_train))
print(len(y_train))
# Out:
# 13196
# 145333

# %%
print(len(X_test))
print(len(y_test))
# Out:
# 48852
# 48852

# %%
X_test = np.delete(X_test, drop_test, axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
y_test = np.delete(y_test, drop_test, axis=0)

# %%
print(len(X_test))
print(len(y_test))
# Out:
# 48745
# 48745

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 54
# 리뷰의 평균 길이 : 10.209078508638981

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
max_len = 30
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 30 이하인 샘플의 비율: 95.02879660503183

# %%
# 전체 데이터의 길이는 30으로 맞춘다.
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100))
model.add(LSTM(128))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/15
# 165/165 [==============================] - 11s 19ms/step - loss: 0.5155 - acc: 0.7426 - val_loss: 0.4232 - val_acc: 0.7981
#
# Epoch 00001: val_acc improved from -inf to 0.79811, saving model to best_model.h5
# Epoch 2/15
# 165/165 [==============================] - 2s 14ms/step - loss: 0.3520 - acc: 0.8485 - val_loss: 0.4737 - val_acc: 0.7924
#
# Epoch 00002: val_acc did not improve from 0.79811
# Epoch 3/15
# 165/165 [==============================] - 2s 14ms/step - loss: 0.3065 - acc: 0.8698 - val_loss: 0.4129 - val_acc: 0.8155
#
# Epoch 00003: val_acc improved from 0.79811 to 0.81553, saving model to best_model.h5
# Epoch 4/15
# 165/165 [==============================] - 2s 14ms/step - loss: 0.2806 - acc: 0.8812 - val_loss: 0.4345 - val_acc: 0.8121
#
# Epoch 00004: val_acc did not improve from 0.81553
# Epoch 5/15
# 165/165 [==============================] - 2s 14ms/step - loss: 0.2629 - acc: 0.8903 - val_loss: 0.4427 - val_acc: 0.8144
#
# Epoch 00005: val_acc did not improve from 0.81553
# Epoch 6/15
# 165/165 [==============================] - 2s 14ms/step - loss: 0.2478 - acc: 0.8997 - val_loss: 0.4481 - val_acc: 0.8167
#
# Epoch 00006: val_acc improved from 0.81553 to 0.81667, saving model to best_model.h5
# Epoch 7/15
# 165/165 [==============================] - 2s 14ms/step - loss: 0.2335 - acc: 0.9030 - val_loss: 0.4675 - val_acc: 0.8125
#
# Epoch 00007: val_acc did not improve from 0.81667
# Epoch 00007: early stopping

# %%
loaded_model = load_model('best_model.h5')

# %%
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 1524/1524 [==============================] - 8s 5ms/step - loss: 1.0539 - acc: 0.5733
#
#  테스트 정확도: 0.5733

# %%
def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - score) * 100))

# %%
sentiment_predict('이 영화 개꿀잼 ㅋㅋㅋ')
# Out:
# 51.31% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('이 영화 핵노잼 ㅠㅠ')
# Out:
# 51.31% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('이딴게 영화냐 ㅉㅉ')
# Out:
# 51.31% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('감독 뭐하는 놈이냐?')
# Out:
# 51.31% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('와 개쩐다 정말 세계관 최강자들의 영화다')
# Out:
# 51.31% 확률로 긍정 리뷰입니다.
